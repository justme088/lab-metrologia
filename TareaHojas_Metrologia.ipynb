# %% [markdown]
# <a href="https://colab.research.google.com/github/justme088/lab-metrologia/blob/main/TareaHojas_Metrologia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Cargar el CSV
df = pd.read_csv('/content/drive/MyDrive/GoogleColab/Metrologia/hojas_datos.csv')

# %%
preview = df

# Visualizador simple de dispersión largo vs ancho
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='largo_cm', y='ancho_cm', hue='hoja', palette='viridis', legend=False)
plt.title('Visualizador de hojas: Largo vs Ancho')
plt.xlabel('Largo (cm)')
plt.ylabel('Ancho (cm)')
plt.grid(True)
plt.show()
preview
# Out:
#     hoja  largo_cm  ancho_cm
# 0      1       6.0       2.0
# 1      2       4.0       2.0
# 2      3       5.0       2.0
# 3      4       5.0       2.0
# 4      5       6.0       2.0
# ..   ...       ...       ...
# 95    96       5.4       3.2
# 96    97       5.6       2.8
# 97    98       7.2       2.3
# 98    99       5.9       3.1
# 99   100       6.5       3.4
#
# [100 rows x 3 columns]

# %%
# Calcular estadísticas
largo_promedio = df['largo_cm'].mean()
largo_std = df['largo_cm'].std()
largo_rango = df['largo_cm'].max() - df['largo_cm'].min()

ancho_promedio = df['ancho_cm'].mean()
ancho_std = df['ancho_cm'].std()
ancho_rango = df['ancho_cm'].max() - df['ancho_cm'].min()

# %%
# Histograma de largo
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.hist(df['largo_cm'], bins=10, color='green', edgecolor='black')
plt.title('Histograma del Largo de las Hojas')
plt.xlabel('Largo (cm)')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

print("Largo de hojas:")
print(f"  Promedio: {largo_promedio:.2f} cm")
print(f"  Desviación estándar: {largo_std:.2f} cm")
print(f"  Rango: {largo_rango:.2f} cm")
# Out:
# Largo de hojas:
#   Promedio: 5.79 cm
#   Desviación estándar: 1.02 cm
#   Rango: 4.60 cm

# %%
# Histograma de ancho
plt.subplot(1, 2, 2)
plt.hist(df['ancho_cm'], bins=10, color='blue', edgecolor='black')
plt.title('Histograma del Ancho de las Hojas')
plt.xlabel('Ancho (cm)')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

print("\nAncho de hojas:")
print(f"  Promedio: {ancho_promedio:.2f} cm")
print(f"  Desviación estándar: {ancho_std:.2f} cm")
print(f"  Rango: {ancho_rango:.2f} cm")
# Out:
# Ancho de hojas:
#   Promedio: 2.57 cm
#   Desviación estándar: 0.59 cm
#   Rango: 3.10 cm
